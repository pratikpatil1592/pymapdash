# %%
import folium
import pandas as pd

# %% [raw]
# folium_map = folium.Map(location=[18.5204, 73.8567],
#                        zoom_start = 1,
#                        tiles = "CartoDB dark_matter")
#
# folium.CircleMarker(location=[18.5204, 73.8567], fill=True).add_to(folium_map)
# folium_map

# %%
seismic_data = pd.read_csv('seismic',delimiter='\t',encoding='utf-8')
seismic_data.head()
# Out:
#     I_D  YEAR  MONTH  DAY  HOUR  MINUTE SECOND  FOCAL_DEPTH  EQ_PRIMARY  \
# 0  5222  1990      2    8   7.0    15.0   32.2         26.0         6.6
# 1  6477  1990      2   28  23.0    43.0   36.6          5.0         5.5
# 2  5223  1990      3    4  19.0    46.0   19.6         10.0         6.1
# 3  7709  1990      3   25  13.0    22.0   55.6         22.0         7.0
# 4  5224  1990      3   25  14.0    17.0   18.8         33.0         6.3
#
#    EQ_MAG_MB      COUNTRY                                      LOCATION_NAME  \
# 0        6.2  PHILIPPINES  PHILIPPINES:  BOHOL, CEBU, CAGAYAN DE ORO, CAM...
# 1        5.5          USA                CALIFORNIA:  S,  CLAREMONT,  COVINA
# 2        5.8     PAKISTAN                  PAKISTAN:  KALAT, QUETTA, MASTUNG
# 3        6.2   COSTA RICA                  COSTA RICA:  PUNTARENAS, SAN JOSE
# 4        6.0   TAJIKISTAN                       TAJIKISTAN:  PAMIR MOUNTAINS
#
#    LATITUDE  LONGITUDE  REGION_CODE
# 0     9.755    124.694          170
# 1    34.140   -117.700          150
# 2    28.925     66.331           60
# 3     9.919    -84.808          100
# 4    37.034     72.942           40

# %%
def by_magnitude(magnitude):

    locations = seismic_data[['EQ_PRIMARY','LATITUDE','LONGITUDE','LOCATION_NAME','DAY','MONTH','YEAR']]
    
    subset = locations[locations["EQ_PRIMARY"].values == magnitude]
    
    total_count = subset.merge(locations)
    return total_count

by_magnitude(6.6)
# Out:
#     EQ_PRIMARY  LATITUDE  LONGITUDE  \
# 0          6.6     9.755    124.694
# 1          6.6    40.149     21.695
# 2          6.6    27.291    100.276
# 3          6.6    37.570     20.656
# 4          6.6    14.374    -91.473
# 5          6.6    30.154     57.605
# 6          6.6   -17.731    -65.431
# 7          6.6    37.106     70.110
# 8          6.6    -8.194    112.413
# 9          6.6    28.343     57.193
# 10         6.6    30.512     79.403
# 11         6.6    13.671    -88.938
# 12         6.6   -16.086    -73.987
# 13         6.6   -27.535    -70.586
# 14         6.6    19.917     95.672
# 15         6.6    35.706   -121.102
# 16         6.6    28.995     58.311
# 17         6.6   -37.695    -73.406
# 18         6.6    24.530    122.694
# 19         6.6    37.226    138.779
# 20         6.6    33.807    130.131
# 21         6.6    30.568    131.093
# 22         6.6    34.064    141.491
# 23         6.6   -10.362    112.892
# 24         6.6    49.277   -128.772
# 25         6.6    37.570    138.478
# 26         6.6   -39.011    178.291
# 27         6.6    39.533     73.824
# 28         6.6    -8.207    118.631
# 29         6.6    -2.515    101.501
# 30         6.6    -8.743    157.477
# 31         6.6    37.001    140.401
# 32         6.6    30.308    102.888
# 33         6.6   -28.886   -176.819
# 34         6.6    35.514     23.252
# 35         6.6    -0.590    131.270
# 36         6.6    36.472     71.131
# 37         6.6    42.862     13.096
# 38         6.6   -21.630    168.884
# 39         6.6    15.802    -93.633
#
#                                         LOCATION_NAME  DAY  MONTH  YEAR
# 0   PHILIPPINES:  BOHOL, CEBU, CAGAYAN DE ORO, CAM...    8      2  1990
# 1   GREECE:  GREVENA-KOZANI, THESSALONIKI, YUGOSLAVIA   13      5  1995
# 2                   CHINA:  YUNNAN PROVINCE:  LIJIANG    3      2  1996
# 3   GREECE:  IONIAN SEA, AMALIAS, GARGALIANOI, KAL...   18     11  1997
# 4       GUATEMALA:  QUEZALTENANGO, SAN MARCOS, SOLOLA   10      1  1998
# 5                         IRAN:  GOLBAF, BAFT, KERMAN   14      3  1998
# 6                 BOLIVIA:  CENTRAL:  AIQUILE, TOTORA   22      5  1998
# 7                    AFGHANISTAN:  BADAKHSHAN, TAKHAR   30      5  1998
# 8            INDONESIA:  JAWA, MALANG, BLITAR, BANTUR   28      9  1998
# 9                            IRAN:  SOUTHERN:  KERMAN    4      3  1999
# 10        INDIA:  CHAMOLI, RUDRAPRAYAG, TEHRI GARHWAL   28      3  1999
# 11  EL SALVADOR: SAN JUAN TEPEZONTES-SAN VICENTE-C...   13      2  2001
# 12  PERU:  CARAVELI, CHALA, ARICA, IQUIQUE, PARINA...    5      7  2001
# 13                            CHILE:  COPIAPO, TALTAL   18      4  2002
# 14  MYANMAR (BURMA):  TAUNGDWINGYI; THAILAND:  BAN...   21      9  2003
# 15      CALIFORNIA:  PASO ROBLES,TEMPLETON,ATASCADERO   22     12  2003
# 16                 IRAN:  SOUTHEASTERN:  BAM, BARAVAT   26     12  2003
# 17                                      CHILE: CANETE    3      5  2004
# 18                                 TAIWAN:  T'AO-YUAN   15     10  2004
# 19                JAPAN:  HONSHU:  NIIGATA PREFECTURE   23     10  2004
# 20                   JAPAN:  KYUSHU:  FUKUOKA, GENKAI   20      3  2005
# 21                              JAPAN:  KYUSHU ISLAND   18     10  1996
# 22                          JAPAN:  EAST COAST HONSHU   19      1  2005
# 23                                   INDONESIA:  JAVA    3      6  1994
# 24                          CANADA:  VANCOUVER ISLAND    2     11  2004
# 25                           JAPAN:  HONSHU:  W COAST   16      7  2007
# 26               NEW ZEALAND:  OFF COAST NORTH ISLAND   20     12  2007
# 27                                   KYRGYZSTAN: NURA    5     10  2008
# 28                        INDONESIA:  SUMABAWA:  BIMA    8     11  2009
# 29           INDONESIA:  SUMATRA:  SOUTHERN:  KERINCI    1     10  2009
# 30                                    SOLOMON ISLANDS    3      1  2010
# 31                                     JAPAN:  HONSHU   11      4  2011
# 32                 CHINA:  SICHUAN PROVINCE:  LONGMEN   20      4  2013
# 33                                   KERMADEC ISLANDS   18      6  1993
# 34                            GREECE:  CRETE:  CHANIA   12     10  2013
# 35                                 INDONESIA:  SORONG   24      9  2015
# 36                   AFGHANISTAN:  KHYBER PAKHTUNKHWA   10      4  2016
# 37                                      ITALY: NORCIA   30     10  2016
# 38                    NEW CALEDONIA:  LOYALTY ISLANDS    1     11  2017
# 39                                MEXICO:  COCOTITLAN   17     12  2015

# %%
def plot_eq_map(total_count):
    folium_map = folium.Map(location=[31.107, 51.678],
                       zoom_start = 2,
                       tiles = "CartoDB dark_matter")
    
    for index, row in total_count.iterrows():
        
        eq_mag = (row["EQ_PRIMARY"])

        popup_text = "Magnitude: {}<br> Location: {}<br> Date: {}/{}/{}"
        popup_text = popup_text.format(row["EQ_PRIMARY"],
                                      row["LOCATION_NAME"],
                                      row["DAY"], row["MONTH"], row["YEAR"])

        radius = eq_mag*2

        if radius >= 14:
            color="#FF0000" # red
        elif radius >= 12 and radius < 14:
            color="#007849" # green
        elif radius >= 8 and radius < 12:
            color="#0A8A9F" # teal
        else:
            color="#FFCE00" # yellow            
            
        folium.CircleMarker(location = (row['LATITUDE'], 
                                        row['LONGITUDE']), 
                            radius = radius,
                            color = color,
                            popup = popup_text,
                            fill=True).add_to(folium_map)
    return folium_map

# %%
total_count = by_magnitude(6.5)
folium_map = plot_eq_map(total_count)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
